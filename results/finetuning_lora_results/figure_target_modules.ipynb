# %%
import json
filenames = [
    f't5_evaluation_results_finetune_r16.json',
    f't5_evaluation_results_finetune_denselayer_r16.json',
    f't5_evaluation_results_finetune_full_r16.json',
             ]
rougeLsums = []
bert_F1s = []
for filename in filenames:
    with open(filename, 'r') as f:
        fulldic = json.load(f)
        rougeLsums.append(fulldic['rouge']['rougeLsum'])
        bert_F1s.append(fulldic['bert']['F1'])

print(rougeLsums)
print(bert_F1s)
# Out:
# [0.2547683626108541, 0.24851685404939106, 0.24851685404939106]
# [0.7401046804730564, 0.7364379792530973, 0.7364379792530973]

# %%
import matplotlib.pyplot as plt
import numpy as np


# Setting up the figure
fig, axes = plt.subplots(1, 2, figsize=(8, 4), sharey=False)

# Colors for before and after fine-tuning
colors = ["#1f77b4", "#ff7f0e"]

# Plotting the data
rs = ['attn block', 'dense layer', 'full']
xs = range(len(rs))
axes[0].set_title("ROUGE-Lsum score")
axes[1].set_title("BERT F1 score")
axes[0].set_xticks(xs)
axes[0].set_xticklabels(rs)
axes[1].set_xticks(xs)
axes[1].set_xticklabels(rs)
axes[0].set_xlabel("Rank of LoRA perturbation")
axes[1].set_xlabel("Rank of LoRA perturbation")
axes[0].bar(xs, rougeLsums, label="ROUGE-Lsum", color=colors[0] )
axes[1].bar(xs, bert_F1s, label="BERT F1", color=colors[1])
axes[0].set_ylim(.2, .3)
axes[1].set_ylim(.7, .8)
# Out:
# (0.7, 0.8)
